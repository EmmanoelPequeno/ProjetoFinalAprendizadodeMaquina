# %% [markdown]
# ## Projeto Final Aprendizado de Máquina

# %% [markdown]
# #### Duplas: Aliança BA-AL e Nemphis & Nempharey

# %% [markdown]
# #### Integrantes: Davi J.A. Pereira, Diogo P. de L. Carvalho, Mayllon E.P.S. Silva, Samuel S. de Araújo

# %% [markdown]
# ### Notebook 3: RIDGE

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import Ridge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score as r2
from sklearn.decomposition import PCA
from optuna import create_study, Trial

# %% [markdown]
# # RIDGE REGRESSION

# %% [markdown]
# Em tradução livre regressão de cume ou de crista, é um modelo que considera a variância(medida de quão próximo é o modelo dos dados, por exemplo o RMSE é uma das formas de medir) e o BIAS(medida que considera o alinhamento do gráfico com as amostras, ou seja, a incapacidade de chegar a relação correta entre os dados).

# %% [markdown]
# As imagens abaixo são da referência [2].
#
# ![image.png](attachment:b697e972-de77-4788-b057-bcaa1fe8b002.png)

# %% [markdown]
# Na imagem acima, temos na direita um exemplo de regressão linear que considera apenas as distâncias em relação aos pontos(variância, enquanto o exemplo da esquerda mostra a distância em relação aos pontos(variância) e a distância em relação relação dos dados(BIAS).
#
# A parte do BIAS no modelo é conhecida como penalidade da regressão Ridge e ela é calculada multiplicando λ pelo quadrado do peso de cada feature.

# %% [markdown]
# A função de perda do modelo de regressão ridge é dada por: **Min(||Y – X(theta)||^2 + λ||theta||^2)**

# %% [markdown]
# Onde **|Y – X(theta)||^2** representa a doma dos quadrados dos resíduos, utilizada para o ajuste do modelo de regressão linear padrão.
#
# E **λ||theta||^2** é a penalidade da parte do BIAS, no qual podemos ver o  λ multiplicando o quadrado de uma única feature

# %% [markdown]
# Ao mudar o valor de  λ, ajustamos a função de perda, quanto maior for  λ, maior vai ser a penalidade e menor a grandeza dos coeficientes. Dessa forma, diminui-se a complexidade do modelo.

# %% [markdown]
# Um ponto que vale ressaltar é que λ é denotado, na função de regressão linear de diversas bibliotecas, como alpha. Logo o parâmetro alpha dos modelos indica o  λ da função de perda.

# %% [markdown]
# Em um modelo de regressão linear simples, temos **Y = X*B + e**, onde y é a variável dependente, x as independentess, B são os coeficientes de regressão e **e** representa os resíduos.

# %% [markdown]
# Primeiro, é necessário normalizar as variáveis da função dada pelo modelo, tanto as dependentes quanto as independentes(isso é feito subtraindo suas médias e dividindo pelo desvio padrão). Apesar do modelo utilizar a normalização para o fit, o resultado final é convertido para a escala original.
#
# Um dos pontos mais importantes de regressão de Ridge é a compensação de variância e viés, onde temos uma relação direta com λ. Quanto maior for λ, maior o viés e menor a variância.

# %% [markdown]
# # Ridge regressor no skilearn

# %% [markdown]
# Na biblioteca scikitlearn, o modelo de regressão ridge tem os seguintes parâmetros:
#
# alpha: O alpha representa o valor de lambda da função de custo como foi discutido acima.
#
# fit_intercept: É do tipo lógico e determina de será usado interceptação ou não durante os cálculos.
#
# copy_X: É do tipo lógico e determina de as features vão ser sobescristas ou não.
#
# max_inter: É do tipo inteiro e determina o número máximos de interação o solucionador de gradiente conjugado.
#
# tol: É do tipo float e determina o tipo de convergência, ele possui uma aplicação de determinação diferente para cada tipo de solucionador. Sendo as determinações:
#
#     'svd': tol não tem impacto.
#
#     'cholesky': tol não tem impacto.
#
#     'sparse_cg': norma de resíduos menores que tol.
#
#     'lsqr': tol é definido como atol e btol de scipy.sparse.linalg.lsqr, que controlam a norma do vetor residual em termos das normas   da matriz e dos coeficientes.
#
#     'sag' e 'saga': variação relativa do coef menor que tol.
#
#     'lbfgs': máximo do gradiente absoluto (projetado)=max|residuals| menor que tol.
#
# solver: Determina o tipo de solucionador, sendo eles:
# auto' escolhe o solucionador automaticamente com base no tipo de dados.
#
#     'svd' usa uma decomposição de valor singular de X para calcular os coeficientes de Ridge. É o solucionador mais estável, em particular mais estável para matrizes singulares do que 'cholesky', ao custo de ser mais lento.
#
#     'cholesky' usa a função padrão scipy.linalg.solve para obter uma solução de formato fechado.
#
#     'sparse_cg' usa o solucionador de gradiente conjugado encontrado em scipy.sparse.linalg.cg. Como um algoritmo iterativo, este solucionador é mais apropriado que 'cholesky' para dados de grande escala (possibilidade de definir tole max_iter).
#
#     'lsqr' usa a rotina dedicada de mínimos quadrados regularizados scipy.sparse.linalg.lsqr. É o mais rápido e utiliza um procedimento iterativo.
#
#     'sag' usa uma descida de gradiente médio estocástico e 'saga' usa sua versão melhorada e imparcial chamada SAGA. Ambos os métodos também usam um procedimento iterativo e geralmente são mais rápidos que outros solucionadores quando n_samples e n_features são grandes. Observe que a convergência rápida 'sag' e 'saga' só é garantida em recursos com aproximadamente a mesma escala. Você pode pré-processar os dados com um escalonador de sklearn.preprocessing.
#
#     'lbfgs' usa o algoritmo L-BFGS-B implementado em scipy.optimize.minimize. Só pode ser usado quando positive for True.
#
# positive: É lógico e determina se os coeficientes têm que ser positivos ou se não precisam. Só é dado o valor true para o solucionador lbfgs
#
# random_state: É inteiro e determina radomização para os soluncionadores sag e saga

# %% [markdown]
# # Aplicando o modelo na previsão de Temperatura Crítica de materiais

# %% [markdown]
# Como já foi explicado, utilizou-se do método VIF para tratar os dados do dataset(o dataset tratado está disponibilizado como **Dataset_superconductors_2.csv** no github)

# %%
data_principal = pd.read_csv("Dataset_superconductors_2.csv")
data_principal
# Out:
#        mean_atomic_mass  wtd_range_atomic_mass  std_atomic_mass   gmean_fie  \
# 0             88.944468              31.794921        51.968828  718.152900
# 1             92.729214              36.161939        47.094633  720.605511
# 2             88.944468              35.741099        51.968828  718.152900
# 3             88.944468              33.768010        51.968828  718.152900
# 4             88.944468              27.848743        51.968828  718.152900
# ...                 ...                    ...              ...         ...
# 21258        106.957877              15.504479        65.764081  651.611213
# 21259         92.266740               7.353333        69.232655  702.115184
# 21260         99.663190              53.041104         6.756810  730.207231
# 21261         99.663190              31.115202         6.756810  730.207231
# 21262         87.468333              43.144000        29.905282  852.858789
#
#        wtd_range_fie  mean_atomic_radius  wtd_range_atomic_radius  \
# 0         735.985714          160.250000                42.914286
# 1         743.164286          161.200000                50.571429
# 2         743.164286          160.250000                49.314286
# 3         739.575000          160.250000                46.114286
# 4         728.807143          160.250000                36.514286
# ...              ...                 ...                      ...
# 21258     427.546667          176.500000                57.808889
# 21259     659.771429          159.200000                20.285714
# 21260     370.180000          183.500000               124.600000
# 21261     208.799000          183.500000                84.230000
# 21262     285.510000          127.333333                67.700000
#
#        std_atomic_radius  wtd_entropy_Density  range_Density  ...  \
# 0              75.237540             0.814598       8958.571  ...
# 1              67.321319             0.914802      10488.571  ...
# 2              75.237540             0.760305       8958.571  ...
# 3              75.237540             0.788889       8958.571  ...
# 4              75.237540             0.859811       8958.571  ...
# ...                  ...                  ...            ...  ...
# 21258          45.883003             1.110551       7511.000  ...
# 21259          67.211309             1.080432      11848.571  ...
# 21260          14.500000             0.572700       3453.000  ...
# 21261          14.500000             0.667210       3453.000  ...
# 21262          21.853045             0.874139       3055.000  ...
#
#        mean_ThermalConductivity  wtd_gmean_ThermalConductivity  \
# 0                    107.756645                       0.621979
# 1                    172.205316                       0.619735
# 2                    107.756645                       0.619095
# 3                    107.756645                       0.620535
# 4                    107.756645                       0.624878
# ...                         ...                            ...
# 21258                 65.500000                      95.001493
# 21259                132.805316                       1.577047
# 21260                 62.500000                      57.038314
# 21261                 62.500000                      58.781651
# 21262                 27.506667                      12.919996
#
#        entropy_ThermalConductivity  wtd_entropy_ThermalConductivity  \
# 0                         0.308148                         0.262848
# 1                         0.847404                         0.567706
# 2                         0.308148                         0.250477
# 3                         0.308148                         0.257045
# 4                         0.308148                         0.272820
# ...                            ...                              ...
# 21258                     1.029002                         0.634332
# 21259                     0.949904                         0.745515
# 21260                     0.683870                         0.559446
# 21261                     0.683870                         0.659671
# 21262                     0.194158                         0.142553
#
#        wtd_range_ThermalConductivity  gmean_Valence  range_Valence  \
# 0                          57.127669       2.213364              1
# 1                          51.413383       1.888175              2
# 2                          57.127669       2.213364              1
# 3                          57.127669       2.213364              1
# 4                          57.127669       2.213364              1
# ...                              ...            ...            ...
# 21258                      83.048889       3.223710              1
# 21259                      76.176553       2.168944              1
# 21260                      29.000000       4.472136              1
# 21261                      15.250000       4.472136              1
# 21262                      39.448000       4.762203              3
#
#        wtd_range_Valence  wtd_std_Valence  critical_temp
# 0               1.085714         0.437059          29.00
# 1               1.128571         0.468606          26.00
# 2               1.114286         0.444697          19.00
# 3               1.100000         0.440952          22.00
# 4               1.057143         0.428809          23.00
# ...                  ...              ...            ...
# 21258           2.168889         0.496904           2.44
# 21259           0.904762         0.212959         122.10
# 21260           3.200000         0.400000           1.98
# 21261           2.210000         0.462493           1.84
# 21262           1.800000         1.500000          12.80
#
# [21263 rows x 30 columns]

# %%
X = ['mean_atomic_mass', 'wtd_range_atomic_mass', 'std_atomic_mass',
       'gmean_fie', 'wtd_range_fie', 'mean_atomic_radius',
       'wtd_range_atomic_radius', 'std_atomic_radius',
       'wtd_entropy_Density', 'range_Density', 'wtd_range_Density',
       'mean_ElectronAffinity', 'wtd_gmean_ElectronAffinity',
       'wtd_entropy_ElectronAffinity', 'range_ElectronAffinity',
       'wtd_std_ElectronAffinity', 'gmean_FusionHeat', 'range_FusionHeat',
       'wtd_range_FusionHeat', 'wtd_std_FusionHeat',
       'mean_ThermalConductivity', 'wtd_gmean_ThermalConductivity',
       'entropy_ThermalConductivity', 'wtd_entropy_ThermalConductivity',
       'wtd_range_ThermalConductivity', 'gmean_Valence', 'range_Valence',
       'wtd_range_Valence', 'wtd_std_Valence']

y = ["critical_temp"]

# %%
data_principal = data_principal.apply(pd.to_numeric)

# %%
TAMANHO_TESTE = 0.1


X = ['mean_atomic_mass', 'wtd_range_atomic_mass', 'std_atomic_mass',
       'gmean_fie', 'wtd_range_fie', 'mean_atomic_radius',
       'wtd_range_atomic_radius', 'std_atomic_radius',
       'wtd_entropy_Density', 'range_Density', 'wtd_range_Density',
       'mean_ElectronAffinity', 'wtd_gmean_ElectronAffinity',
       'wtd_entropy_ElectronAffinity', 'range_ElectronAffinity',
       'wtd_std_ElectronAffinity', 'gmean_FusionHeat', 'range_FusionHeat',
       'wtd_range_FusionHeat', 'wtd_std_FusionHeat',
       'mean_ThermalConductivity', 'wtd_gmean_ThermalConductivity',
       'entropy_ThermalConductivity', 'wtd_entropy_ThermalConductivity',
       'wtd_range_ThermalConductivity', 'gmean_Valence', 'range_Valence',
       'wtd_range_Valence', 'wtd_std_Valence']

y = ["critical_temp"]

# %%
data_principal = data_principal.reindex(X + y, axis=1)

# %%
targ = list() 
feat = list(data_principal.columns[:-1])
targ.append(data_principal.columns[-1])

# %%
X = data_principal.reindex(feat, axis=1)
y = data_principal.reindex(targ, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
y_test = y_test.values

# %% [markdown]
# Vamos usar a biblioteca optuna para rodar o modelo diversas vezes com parâmetos distintos, com o intuito de encontrar o melhor ajuste possível da previsão

# %% [markdown]
# ## Modelo e espaço de busca

# %% [markdown]
# Para o modelo e o espaço de busca, tem-se a limitação da relação dos parâmetros. Isso ocorre pois o parâmetro positive só pode ser True para o solucionador lbfgs, ou seja, é impossível criar um modelo com outro solucionador e o parâmetro positive como True. Logo, é necessário criar dois espaçoes de busca, um só para o solucionador lbfgs.
#
# Outro fator é o parâmetro radom_state que só pode assumir valor para os solucionadores sag e saga, nesse caso, foi optado por coloca-lo como None para não haver problemas de imcompatibilidade.

# %%
def cria_instancia_modelo(trial):
    """Cria uma instância do modelo.

    Args:
      trial: objeto tipo Trial do optuna.

    Returns:
      Uma instância do modelo desejado.
    """

    parametros = {
        
        "alpha": trial.suggest_float("alpha", 0, 5),

        "fit_intercept": trial.suggest_categorical("fit_intercept", ["True", "False"]),

        "copy_X": False,

        "max_iter": trial.suggest_int("max_iter", 1000, 15000),

        "tol": trial.suggest_float("tol", 10**(-4), 10**(-1)),

        "solver": trial.suggest_categorical("solver", ["auto", "svd", "cholesky", "lsqr", "sparse_cg", "sag", "saga"]),

        "random_state": None,
    }

    model = Ridge(**parametros)

    return model

# %%
def cria_instancia_modelo2(trial):
    """Cria uma instância do modelo.

    Args:
      trial: objeto tipo Trial do optuna.

    Returns:
      Uma instância do modelo desejado.
    """

    parametros = {
        
        "alpha": trial.suggest_float("alpha", 0, 5),

        "fit_intercept": trial.suggest_categorical("fit_intercept", ["True", "False"]),

        "copy_X": False,

        "max_iter": trial.suggest_int("max_iter", 1000, 15000),

        "tol": trial.suggest_float("tol", 10**(-4), 10**(-1)),

        "solver": "lbfgs",

        "positive": True,

        "random_state": None,
    }

    model = Ridge(**parametros)

    return model

# %% [markdown]
# ## Função objetivo

# %% [markdown]
# A função objetivo de um problema de otimização é a função que irá computar a nossa métrica de interesse. Neste caso, a métrica de interesse é o RMSE médio obtido por validação cruzada.

# %%
NUM_FOLDS = 10
NUM_TENTATIVAS = 200

# %%
def funcao_objetivo(
    trial,
    X,
    y,
    num_folds=NUM_FOLDS,
):
    """Função objetivo do optuna

    Referencia:
      https://medium.com/@walter_sperat/ using-optuna-with-sklearn-the-right-way-part-1-6b4ad0ab2451
    """

    modelo = cria_instancia_modelo(trial)

    metricas = cross_val_score(
        modelo,
        X,
        y,
        scoring="neg_root_mean_squared_error",
        cv=NUM_FOLDS,
    )

    # releia sobre scores no sklearn para relembrar porque tem um negativo abaixo
    return -metricas.mean()

# %%
def funcao_objetivo2(
    trial,
    X,
    y,
    num_folds=NUM_FOLDS,
):
    """Função objetivo do optuna

    Referencia:
      https://medium.com/@walter_sperat/ using-optuna-with-sklearn-the-right-way-part-1-6b4ad0ab2451
    """

    modelo = cria_instancia_modelo2(trial)

    metricas = cross_val_score(
        modelo,
        X,
        y,
        scoring="neg_root_mean_squared_error",
        cv=NUM_FOLDS,
    )

    # releia sobre scores no sklearn para relembrar porque tem um negativo abaixo
    return -metricas.mean()

# %% [markdown]
# ## Otimização de hiperparâmetros sem lbfgs

# %%
objeto_de_estudo = create_study(direction="minimize")
# Out:
# [I 2023-11-15 23:34:01,329] A new study created in memory with name: no-name-d1dd4302-8722-4bfe-8fc5-9a67f263a007

# %%
def funcao_objetivo_parcial(trial):
    return funcao_objetivo(trial, X_train, y_train)

# %%
objeto_de_estudo.optimize(funcao_objetivo_parcial, n_trials=NUM_TENTATIVAS)
# Out:
# [I 2023-11-15 23:34:01,745] Trial 0 finished with value: 20.185516395048136 and parameters: {'alpha': 4.748056911318516, 'fit_intercept': 'False', 'max_iter': 1234, 'tol': 0.030527152764701283, 'solver': 'cholesky'}. Best is trial 0 with value: 20.185516395048136.
# [I 2023-11-15 23:34:02,015] Trial 1 finished with value: 31.309340865664144 and parameters: {'alpha': 0.2661581370060251, 'fit_intercept': 'False', 'max_iter': 10406, 'tol': 0.0485961087294627, 'solver': 'sparse_cg'}. Best is trial 0 with value: 20.185516395048136.
# [I 2023-11-15 23:34:02,313] Trial 2 finished with value: 23.94536447956663 and parameters: {'alpha': 4.123590707635513, 'fit_intercept': 'False', 'max_iter': 8116, 'tol': 0.0133846034123803, 'solver': 'sparse_cg'}. Best is trial 0 with value: 20.185516395048136.
# [I 2023-11-15 23:34:02,797] Trial 3 finished with value: 20.185476519849743 and parameters: {'alpha': 0.026938356236712035, 'fit_intercept': 'False', 'max_iter': 8976, 'tol': 0.03784625758776548, 'solver': 'svd'}. Best is trial 3 with value: 20.185476519849743.
 'solver': 'auto'}. Best is trial 136 with value: 20.185463255130053.
# [I 2023-11-15 23:35:42,722] Trial 199 finished with value: 20.185463291572827 and parameters: {'alpha': 1.501021515499037, 'fit_intercept': 'True', 'max_iter': 11273, 'tol': 0.03882113940842942, 'solver': 'auto'}. Best is trial 136 with value: 20.185463255130053.

# %% [markdown]
# # Otimização para o solucionador LBFGS

# %%
NUM_TENTATIVAS = 100

# %%
objeto_de_estudo2 = create_study(direction="minimize")
# Out:
# [I 2023-11-15 23:35:42,783] A new study created in memory with name: no-name-9589cc0b-8036-4097-9357-d384048178b6

# %%
def funcao_objetivo_parcial(trial):
    return funcao_objetivo2(trial, X_train, y_train)

# %%
objeto_de_estudo2.optimize(funcao_objetivo_parcial, n_trials=NUM_TENTATIVAS)
# Out:
# [I 2023-11-15 23:35:43,203] Trial 0 finished with value: 32.50211749447011 and parameters: {'alpha': 3.827561972763445, 'fit_intercept': 'False', 'max_iter': 11248, 'tol': 0.05166630569941873}. Best is trial 0 with value: 32.50211749447011.
# [I 2023-11-15 23:35:43,523] Trial 1 finished with value: 33.126696459059225 and parameters: {'alpha': 2.6779415992802678, 'fit_intercept': 'False', 'max_iter': 8445, 'tol': 0.07913350054927222}. Best is trial 0 with value: 32.50211749447011.
# [I 2023-11-15 23:35:43,789] Trial 2 finished with value: 33.12669645905919 and parameters: {'alpha': 4.025492428055503, 'fit_intercept': 'True', 'max_iter': 10610, 'tol': 0.09344478838763859}. Best is trial 0 with value: 32.50211749447011.
# [I 2023-11-15 23:35:44,215] Trial 3 finished with value: 27.445937620107657 and parameters: {'alpha': 0.6801980817100756, 'fit_intercept': 'True', 'max_iter': 8221, 'tol': 0.01718981757728709}. Best is trial 3 with value: 27.445937620107657.
# [I 2023-11-15 23:35:44,591] Trial 4 finished with value: 27.445937606240296 and parameters: {'alpha': 2.3920806136146204, 'fit_intercept': 'False', 'max_iter': 6711, 'tol': 0.023558604144244277}. Best is trial 4 with value: 27.445937606240296.
# [I 2023-11-15 23:35:44,965] Trial 5 finished with value: 27.52470806950391 and parameters: {'alpha': 1.614218625519901, 'fit_intercept': 'False', 'max_iter': 6458, 'tol': 0.03131623503130352}. Best is trial 4 with value: 27.445937606240296.
# [I 2023-11-15 23:35:45,268] Trial 6 finished with value: 32.502117494461615 and parameters: {'alpha': 1.6061501991210125, 'fit_intercept': 'False', 'max_iter': 2807, 'tol': 0.0493997558294194}. Best is trial 4 with value: 27.445937606240296.
# [I 2023-11-15 23:35:45,565] Trial 7 finished with value: 32.502117494460805 and parameters: {'alpha': 1.3566879123465825, 'fit_intercept': 'False', 'max_iter': 7211, 'tol': 0.062201786664792154}. Best is trial 4 with value: 27.445937606240296.
# [I 2023-11-15 23:35:45,845] Trial 8 finished with value: 33.126696459059254 and parameters: {'alpha': 1.7562258684104144, 'fit_intercept': 'False', 'max_iter': 2432, 'tol': 0.08283455341352787}. Best is trial 4 with value: 27.445937606240296.
# [I 2023-11-15 23:35:46,115] Trial 9 finished with value: 33.12669645905926 and parameters: {'alpha': 1.3730000799703734, 'fit_intercept': 'False', 'max_iter': 9046, 'tol': 0.09960057650725869}. Best is trial 4 with value: 27.445937606240296.
# [I 2023-11-15 23:35:46,596] Trial 10 finished with value: 26.806004413252474 and parameters: {'alpha': 4.940454709825403, 'fit_intercept': 'True', 'max_iter': 14787, 'tol': 0.0032244555848391643}. Best is trial 10 with value: 26.806004413252474.
. Best is trial 59 with value: 25.82453584843874.
# [I 2023-11-15 23:36:23,413] Trial 98 finished with value: 26.807947721319522 and parameters: {'alpha': 1.2863930672322799, 'fit_intercept': 'False', 'max_iter': 12182, 'tol': 0.0019261402363081462}. Best is trial 59 with value: 25.82453584843874.
# [I 2023-11-15 23:36:23,718] Trial 99 finished with value: 32.99183999058303 and parameters: {'alpha': 3.0527291115662565, 'fit_intercept': 'False', 'max_iter': 5343, 'tol': 0.06812657354567024}. Best is trial 59 with value: 25.82453584843874.

# %% [markdown]
# ## Observando resultados

# %% [markdown]
# Vamos observar os resultados.

# %%
df = objeto_de_estudo.trials_dataframe()

df
# Out:
#      number      value             datetime_start          datetime_complete  \
# 0         0  20.185516 2023-11-15 23:34:01.447778 2023-11-15 23:34:01.745845
# 1         1  31.309341 2023-11-15 23:34:01.754200 2023-11-15 23:34:02.015247
# 2         2  23.945364 2023-11-15 23:34:02.015247 2023-11-15 23:34:02.313355
# 3         3  20.185477 2023-11-15 23:34:02.318625 2023-11-15 23:34:02.797592
# 4         4  24.612973 2023-11-15 23:34:02.806610 2023-11-15 23:34:04.831802
# ..      ...        ...                        ...                        ...
# 195     195  20.185463 2023-11-15 23:35:41.202464 2023-11-15 23:35:41.497795
# 196     196  20.185464 2023-11-15 23:35:41.514364 2023-11-15 23:35:41.800074
# 197     197  20.185464 2023-11-15 23:35:41.815311 2023-11-15 23:35:42.120409
# 198     198  20.185463 2023-11-15 23:35:42.128418 2023-11-15 23:35:42.402232
# 199     199  20.185463 2023-11-15 23:35:42.420371 2023-11-15 23:35:42.722134
#
#                   duration  params_alpha params_fit_intercept  \
# 0   0 days 00:00:00.298067      4.748057                False
# 1   0 days 00:00:00.261047      0.266158                False
# 2   0 days 00:00:00.298108      4.123591                False
# 3   0 days 00:00:00.478967      0.026938                False
# 4   0 days 00:00:02.025192      4.622263                 True
# ..                     ...           ...                  ...
# 195 0 days 00:00:00.295331      1.449249                 True
# 196 0 days 00:00:00.285710      1.867272                 True
# 197 0 days 00:00:00.305098      1.315205                 True
# 198 0 days 00:00:00.273814      1.612538                 True
# 199 0 days 00:00:00.301763      1.501022                 True
#
#      params_max_iter params_solver  params_tol     state
# 0               1234      cholesky    0.030527  COMPLETE
# 1              10406     sparse_cg    0.048596  COMPLETE
# 2               8116     sparse_cg    0.013385  COMPLETE
# 3               8976           svd    0.037846  COMPLETE
# 4              11904           sag    0.061366  COMPLETE
# ..               ...           ...         ...       ...
# 195            14432          auto    0.043712  COMPLETE
# 196            13596          auto    0.036711  COMPLETE
# 197            14621          auto    0.093441  COMPLETE
# 198             1281          auto    0.033762  COMPLETE
# 199            11273          auto    0.038821  COMPLETE
#
# [200 rows x 11 columns]

# %%
df2 = objeto_de_estudo2.trials_dataframe()

df2
# Out:
#     number      value             datetime_start          datetime_complete  \
# 0        0  32.502117 2023-11-15 23:35:42.864475 2023-11-15 23:35:43.203199
# 1        1  33.126696 2023-11-15 23:35:43.203199 2023-11-15 23:35:43.523990
# 2        2  33.126696 2023-11-15 23:35:43.534555 2023-11-15 23:35:43.789490
# 3        3  27.445938 2023-11-15 23:35:43.789490 2023-11-15 23:35:44.215551
# 4        4  27.445938 2023-11-15 23:35:44.215551 2023-11-15 23:35:44.591281
# ..     ...        ...                        ...                        ...
# 95      95  33.126696 2023-11-15 23:36:21.974059 2023-11-15 23:36:22.244392
# 96      96  27.445938 2023-11-15 23:36:22.251973 2023-11-15 23:36:22.616978
# 97      97  27.445938 2023-11-15 23:36:22.624070 2023-11-15 23:36:22.989977
# 98      98  26.807948 2023-11-15 23:36:22.995669 2023-11-15 23:36:23.413784
# 99      99  32.991840 2023-11-15 23:36:23.429607 2023-11-15 23:36:23.718099
#
#                  duration  params_alpha params_fit_intercept  params_max_iter  \
# 0  0 days 00:00:00.338724      3.827562                False            11248
# 1  0 days 00:00:00.320791      2.677942                False             8445
# 2  0 days 00:00:00.254935      4.025492                 True            10610
# 3  0 days 00:00:00.426061      0.680198                 True             8221
# 4  0 days 00:00:00.375730      2.392081                False             6711
# ..                    ...           ...                  ...              ...
# 95 0 days 00:00:00.270333      1.531102                False            13043
# 96 0 days 00:00:00.365005      1.745484                False             7328
# 97 0 days 00:00:00.365907      2.773806                False             6923
# 98 0 days 00:00:00.418115      1.286393                False            12182
# 99 0 days 00:00:00.288492      3.052729                False             5343
#
#     params_tol     state
# 0     0.051666  COMPLETE
# 1     0.079134  COMPLETE
# 2     0.093445  COMPLETE
# 3     0.017190  COMPLETE
# 4     0.023559  COMPLETE
# ..         ...       ...
# 95    0.095539  COMPLETE
# 96    0.010019  COMPLETE
# 97    0.008294  COMPLETE
# 98    0.001926  COMPLETE
# 99    0.068127  COMPLETE
#
# [100 rows x 10 columns]

# %% [markdown]
# Vamos checar qual foi o melhor resultado.

# %%
melhor_trial1 = objeto_de_estudo.best_trial
melhor_trial2 = objeto_de_estudo2.best_trial

if melhor_trial1 > melhor_trial2:
    melhor_trial = melhor_trial1
    LBFGS = "Não foi melhor"
else:
    melhor_trial = melhor_trial2
    LBFGS = "Foi melhor"

print(f"O LBFG: {LBFGS} que os outros solucionadores")
print(f"Número do melhor trial: {melhor_trial.number}")
print(f"Parâmetros do melhor trial: {melhor_trial.params}")
# Out:
# O LBFG: Não foi melhor que os outros solucionadores
# Número do melhor trial: 136
# Parâmetros do melhor trial: {'alpha': 1.5828437484934244, 'fit_intercept': 'True', 'max_iter': 12438, 'tol': 0.09764727072237589, 'solver': 'auto'}

# %% [markdown]
# Finalmente, vamos criar um modelo com os melhores hiperparâmetros encontrados e checar a sua performance.

# %%
modelo = cria_instancia_modelo(melhor_trial)
modelo.fit(X_train, y_train)

y_verdadeiro = y_test
y_previsao = modelo.predict(X_test)

# %% [markdown]
# Métricas do modelo

# %%
RMSE = mean_squared_error(y_verdadeiro, y_previsao, squared=False)

print(RMSE)

MAE = mae(y_verdadeiro, y_previsao)

print(MAE)

R2 = r2(y_verdadeiro, y_previsao)

print(R2)
# Out:
# 19.60825863227412
# 15.71011220143773
# 0.6647328698516788

# %% [markdown]
# # PCA para visualização gráfica

# %% [markdown]
# Vamos diminuir a dimensionalidade do dataser para ser possível a visualização da correlação entre as duas features principais e o target

# %%
medias = X.mean(axis=0)

X_centralizado = X - medias

# %%
matriz_cov = np.cov(X, rowvar=False)

autovalores, autovetores = np.linalg.eigh(matriz_cov)

indices_ordenados = np.argsort(autovalores)[::-1]

autovalores_ordenados = autovalores[indices_ordenados]
autovetores_ordenados = autovetores[:, indices_ordenados]

matriz_cargas = autovetores_ordenados

nomes_componentes = [f"PC{i+1}" for i in range(X.shape[1])]

df_matriz_cargas = pd.DataFrame(
    matriz_cargas,
    columns=nomes_componentes,
    index= X.columns,
)

df_matriz_cargas
# Out:
#                                       PC1       PC2       PC3       PC4  \
# mean_atomic_mass                -0.001544  0.003924 -0.009748  0.102905
# wtd_range_atomic_mass           -0.000323  0.009299 -0.001470  0.000877
# std_atomic_mass                 -0.003394 -0.001469  0.006325 -0.001215
# gmean_fie                       -0.003282 -0.002668 -0.074594 -0.838311
# wtd_range_fie                   -0.009855 -0.012852  0.991629 -0.060625
# mean_atomic_radius              -0.000484  0.001471  0.017461  0.169204
# wtd_range_atomic_radius          0.001316  0.009885  0.005325  0.026647
# std_atomic_radius               -0.001859 -0.004263  0.038579 -0.048433
# wtd_entropy_Density             -0.000026 -0.000067 -0.000129  0.000209
# range_Density                   -0.996356 -0.084118 -0.010936  0.006113
# wtd_range_Density               -0.084329  0.996199  0.012264 -0.007344
# mean_ElectronAffinity           -0.000781  0.000355 -0.017537 -0.185660
# wtd_gmean_ElectronAffinity      -0.000642  0.000159  0.049952 -0.090673
# wtd_entropy_ElectronAffinity    -0.000022 -0.000032 -0.000396 -0.000612
# range_ElectronAffinity          -0.004666 -0.006570  0.005184 -0.421079
# wtd_std_ElectronAffinity        -0.001708 -0.002632 -0.003929 -0.113025
# gmean_FusionHeat                 0.000359  0.001439 -0.014261  0.007017
# range_FusionHeat                -0.000097 -0.000162 -0.008415 -0.051895
# wtd_range_FusionHeat             0.000492  0.001288  0.001156 -0.007214
# wtd_std_FusionHeat              -0.000017 -0.000070 -0.004594 -0.019080
# mean_ThermalConductivity        -0.001957 -0.001366  0.043103  0.062465
# wtd_gmean_ThermalConductivity    0.001174  0.007723 -0.051066  0.090052
# entropy_ThermalConductivity     -0.000016 -0.000003 -0.000159  0.000595
# wtd_entropy_ThermalConductivity -0.000011 -0.000008 -0.000548  0.000227
# wtd_range_ThermalConductivity   -0.002019  0.001359  0.035595  0.056899
# gmean_Valence                    0.000031  0.000208 -0.001701  0.000143
# range_Valence                   -0.000080 -0.000024 -0.000953 -0.002979
# wtd_range_Valence                0.000033  0.000271  0.000793  0.000032
# wtd_std_Valence                 -0.000017  0.000005 -0.000719 -0.000989
#
#                                       PC5       PC6       PC7       PC8  \
# mean_atomic_mass                -0.122568  0.130202 -0.384892  0.221986
# wtd_range_atomic_mass           -0.078030  0.052365 -0.050954 -0.016309
# std_atomic_mass                  0.022236  0.057243  0.007517  0.065045
# gmean_fie                       -0.130320 -0.415618  0.062639  0.206811
# wtd_range_fie                   -0.049450 -0.040762  0.019164 -0.036951
# mean_atomic_radius              -0.004599  0.100559 -0.056701  0.096341
# wtd_range_atomic_radius         -0.061826 -0.031698  0.142779 -0.231930
# std_atomic_radius                0.108183  0.090395  0.103781  0.150463
# wtd_entropy_Density              0.000848  0.001862  0.000804  0.000390
# range_Density                   -0.003374 -0.002682  0.000186 -0.001932
# wtd_range_Density                0.001377  0.005644  0.003214  0.003960
# mean_ElectronAffinity            0.066942  0.064794 -0.517848 -0.140822
# wtd_gmean_ElectronAffinity       0.048891 -0.016548 -0.716616 -0.022323
# wtd_entropy_ElectronAffinity     0.000815  0.001706  0.000695  0.000926
# range_ElectronAffinity           0.364747  0.679323  0.100786 -0.286284
# wtd_std_ElectronAffinity         0.122722  0.223733  0.011381 -0.038903
# gmean_FusionHeat                -0.020599 -0.079258 -0.024400 -0.127056
# range_FusionHeat                 0.038535 -0.083813  0.089461 -0.301207
# wtd_range_FusionHeat             0.012778 -0.061339  0.015337 -0.164855
# wtd_std_FusionHeat               0.009319 -0.029676  0.021066 -0.106434
# mean_ThermalConductivity         0.500596 -0.310592 -0.018673 -0.078510
# wtd_gmean_ThermalConductivity    0.278927 -0.379497 -0.090351 -0.549980
# entropy_ThermalConductivity      0.000346  0.000927  0.002832 -0.003729
# wtd_entropy_ThermalConductivity -0.000933  0.000561  0.002168 -0.004888
# wtd_range_ThermalConductivity    0.676619 -0.093825  0.024839  0.508161
# gmean_Valence                   -0.006603 -0.002650 -0.010277 -0.006144
# range_Valence                   -0.001787  0.006024  0.002793 -0.010877
# wtd_range_Valence               -0.003608  0.000167 -0.002453 -0.010137
# wtd_std_Valence                 -0.001024  0.001924  0.000366 -0.003812
#
#                                       PC9      PC10  ...      PC20      PC21  \
# mean_atomic_mass                -0.376787  0.083123  ...  0.102961  0.002020
# wtd_range_atomic_mass           -0.297278  0.066292  ...  0.019954 -0.007671
# std_atomic_mass                  0.035632  0.058839  ... -0.140025  0.000307
# gmean_fie                       -0.103051  0.038067  ... -0.045443 -0.001271
# wtd_range_fie                   -0.012590  0.017284  ...  0.006671  0.003302
# mean_atomic_radius              -0.049338  0.059391  ... -0.281070  0.012678
# wtd_range_atomic_radius         -0.562118  0.543090  ...  0.013870  0.008628
# std_atomic_radius                0.292879  0.084689  ...  0.187637 -0.021798
# wtd_entropy_Density             -0.000428 -0.000482  ...  0.002082 -0.000116
# range_Density                   -0.000034  0.001502  ...  0.000310 -0.000006
# wtd_range_Density                0.009307 -0.009237  ... -0.000456  0.000016
# mean_ElectronAffinity           -0.032911  0.058058  ... -0.035323  0.031171
# wtd_gmean_ElectronAffinity       0.217825  0.053227  ... -0.022093 -0.029811
# wtd_entropy_ElectronAffinity     0.000404  0.000538  ...  0.000997  0.003312
# range_ElectronAffinity          -0.108146 -0.034414  ...  0.032007  0.011025
# wtd_std_ElectronAffinity         0.020430 -0.088211  ... -0.011006 -0.059179
# gmean_FusionHeat                 0.047300  0.007400  ...  0.886883 -0.065024
# range_FusionHeat                 0.360768  0.171287  ... -0.113348 -0.267921
# wtd_range_FusionHeat             0.130549  0.154093  ... -0.208252 -0.081611
# wtd_std_FusionHeat               0.135159  0.044935  ...  0.014234  0.951431
# mean_ThermalConductivity        -0.349678 -0.607536  ... -0.038215 -0.004432
# wtd_gmean_ThermalConductivity    0.008979  0.207601  ... -0.029673  0.000631
# entropy_ThermalConductivity      0.000597 -0.000138  ... -0.000453 -0.014166
# wtd_entropy_ThermalConductivity -0.000090 -0.002488  ... -0.001521 -0.007629
# wtd_range_ThermalConductivity    0.050613  0.441758  ...  0.054187  0.012143
# gmean_Valence                   -0.004085  0.003484  ...  0.019208  0.008767
# range_Valence                    0.004952  0.002365  ... -0.032927 -0.064513
# wtd_range_Valence               -0.004907  0.007222  ... -0.013305 -0.033269
# wtd_std_Valence                  0.002417 -0.000646  ... -0.010326 -0.007462
#
#                                      PC22      PC23      PC24      PC25  \
# mean_atomic_mass                -0.010355 -0.004108 -0.003096 -0.001513
# wtd_range_atomic_mass            0.008893  0.009231  0.001441  0.001487
# std_atomic_mass                 -0.001027  0.000508  0.002053 -0.003829
# gmean_fie                       -0.004692 -0.000691 -0.001588  0.001073
# wtd_range_fie                   -0.000192 -0.000055  0.000565  0.000825
# mean_atomic_radius              -0.009023 -0.004797 -0.003916 -0.001028
# wtd_range_atomic_radius         -0.004517 -0.011422  0.007378 -0.000540
# std_atomic_radius               -0.003875  0.021376  0.003765 -0.000932
# wtd_entropy_Density             -0.056038  0.070702 -0.028809  0.495871
# range_Density                    0.000124 -0.000005 -0.000026 -0.000014
# wtd_range_Density                0.000008 -0.000144  0.000067  0.000042
# mean_ElectronAffinity            0.011200 -0.003797 -0.009516  0.005601
# wtd_gmean_ElectronAffinity      -0.005911 -0.007462  0.005754 -0.000076
# wtd_entropy_ElectronAffinity    -0.043338  0.001388  0.049220  0.380744
# range_ElectronAffinity           0.004510  0.003252  0.003141 -0.004786
# wtd_std_ElectronAffinity         0.003865 -0.009910 -0.001465  0.006018
# gmean_FusionHeat                -0.032650 -0.024161 -0.014847 -0.004772
# range_FusionHeat                 0.023521  0.003997  0.002103 -0.008390
# wtd_range_FusionHeat             0.018368 -0.022907  0.022530  0.012891
# wtd_std_FusionHeat              -0.066689  0.003006 -0.023018 -0.001070
# mean_ThermalConductivity        -0.008622  0.002679  0.003503 -0.002747
# wtd_gmean_ThermalConductivity    0.008138  0.002938 -0.000485  0.000513
# entropy_ThermalConductivity     -0.067381  0.002571 -0.091524  0.597343
# wtd_entropy_ThermalConductivity -0.063913  0.018030 -0.088664  0.476398
# wtd_range_ThermalConductivity   -0.007919  0.003413 -0.002810  0.001765
# gmean_Valence                   -0.007360  0.804523  0.586621  0.018174
# range_Valence                   -0.931679 -0.106689  0.147054 -0.097383
# wtd_range_Valence               -0.164652  0.577458 -0.783083 -0.122470
# wtd_std_Valence                 -0.289890 -0.022751  0.004494 -0.013233
#
#                                      PC26      PC27          PC28      PC29
# mean_atomic_mass                -0.000514 -0.001632 -1.142681e-03 -0.001214
# wtd_range_atomic_mass            0.001467  0.000480 -5.234975e-05  0.000271
# std_atomic_mass                  0.001412 -0.001693 -1.023077e-04  0.000223
# gmean_fie                       -0.000372 -0.000107  5.925302e-05 -0.000140
# wtd_range_fie                   -0.000412 -0.000023 -8.935651e-05 -0.000295
# mean_atomic_radius              -0.002436  0.000230  6.730143e-04 -0.000266
# wtd_range_atomic_radius         -0.001395 -0.000320  1.475130e-03  0.000613
# std_atomic_radius                0.002257 -0.003243  8.681232e-04  0.002742
# wtd_entropy_Density             -0.052043  0.616365  3.465602e-01  0.492302
# range_Density                   -0.000005  0.000006 -4.253091e-08  0.000001
# wtd_range_Density                0.000006  0.000028  1.925856e-05  0.000023
# mean_ElectronAffinity            0.002680 -0.003175  2.568393e-04  0.003323
# wtd_gmean_ElectronAffinity      -0.000940  0.001472  1.415944e-03 -0.001437
# wtd_entropy_ElectronAffinity    -0.261905  0.404537 -6.201127e-01 -0.483493
# range_ElectronAffinity          -0.001264 -0.000555  1.537418e-03  0.000612
# wtd_std_ElectronAffinity         0.001854  0.003371 -5.444934e-03 -0.004634
# gmean_FusionHeat                -0.001524  0.001585 -4.712492e-04 -0.001740
# range_FusionHeat                -0.006712  0.001613  1.120442e-03  0.000028
# wtd_range_FusionHeat             0.000483  0.003461 -8.601417e-04 -0.000524
# wtd_std_FusionHeat               0.014235 -0.004889 -2.263221e-03 -0.000233
# mean_ThermalConductivity        -0.000228 -0.000189 -9.179812e-04  0.000761
# wtd_gmean_ThermalConductivity   -0.000257  0.002623 -1.399137e-03  0.000269
# entropy_ThermalConductivity      0.195388 -0.561071 -3.734281e-01  0.370807
# wtd_entropy_ThermalConductivity  0.051527 -0.237742  5.824284e-01 -0.601870
# wtd_range_ThermalConductivity   -0.000185 -0.002824  2.162571e-03 -0.002217
# gmean_Valence                    0.007851 -0.079728  9.301454e-03 -0.006300
# range_Valence                    0.275310  0.076127 -2.478869e-02 -0.032521
# wtd_range_Valence                0.008770  0.048542 -7.102939e-02 -0.033649
# wtd_std_Valence                 -0.900916 -0.265550  1.043316e-01  0.147801
#
# [29 rows x 29 columns]

# %%
NUM_DIMENSOES = 2
matriz_cargas_reduzida = matriz_cargas[:, 0:NUM_DIMENSOES]

print(matriz_cargas_reduzida)
# Out:
# [[-1.54379979e-03  3.92427492e-03]
#  [-3.23400687e-04  9.29866101e-03]
#  [-3.39399647e-03 -1.46922457e-03]
#  [-3.28212433e-03 -2.66849739e-03]
#  [-9.85462221e-03 -1.28521153e-02]
#  [-4.83582160e-04  1.47099928e-03]
#  [ 1.31592190e-03  9.88462501e-03]
#  [-1.85912793e-03 -4.26299854e-03]
#  [-2.56543173e-05 -6.72669690e-05]
#  [-9.96356336e-01 -8.41182324e-02]
#  [-8.43287877e-02  9.96198915e-01]
#  [-7.80583656e-04  3.54844947e-04]
#  [-6.41640614e-04  1.58756666e-04]
#  [-2.17721326e-05 -3.20754658e-05]
#  [-4.66646495e-03 -6.57022102e-03]
#  [-1.70752161e-03 -2.63204943e-03]
#  [ 3.59227238e-04  1.43874222e-03]
#  [-9.67955142e-05 -1.61766174e-04]
#  [ 4.92075747e-04  1.28848913e-03]
#  [-1.73853898e-05 -7.02716216e-05]
#  [-1.95734420e-03 -1.36564471e-03]
#  [ 1.17429651e-03  7.72255470e-03]
#  [-1.63226014e-05 -3.16190199e-06]
#  [-1.06824315e-05 -8.43508418e-06]
#  [-2.01943814e-03  1.35922979e-03]
#  [ 3.07718407e-05  2.08233207e-04]
#  [-8.01496447e-05 -2.44277503e-05]
#  [ 3.26702245e-05  2.71425424e-04]
#  [-1.73471758e-05  5.13651340e-06]]

# %% [markdown]
# Com isso, finalmente podemos aplicar a transformada do PCA. A transformada envolve a multiplicação matricial da matriz de cargas reduzida com os dados centralizados pela média. O símbolo `@` é o símbolo do Python para multiplicação matricial.

# %%
X_reduzido = (matriz_cargas_reduzida.T @ X_centralizado.T).T

print(X_reduzido)
# Out:
#                  0            1
# 0      -183.101260 -1346.459546
# 1     -1715.096817 -1387.708442
# 2      -190.568420 -1258.982896
# 3      -186.834846 -1302.721238
# 4      -175.634068 -1433.936109
# ...            ...          ...
# 21258  1189.290988  -352.638464
# 21259 -3072.615502 -1463.244218
# 21260  5064.876357  1984.836013
# 21261  5257.471263  -270.330164
# 21262  5544.894012  1024.260661
#
# [21263 rows x 2 columns]

# %%
X_reduzido_train, X_reduzido_test, y_train, y_test = train_test_split(X_reduzido, y, test_size=0.1, random_state=42)

ridge = Ridge(alpha=0.1)

ridge.fit(X_reduzido_train, y_train)

# Fazendo previsões no conjunto de teste
y_pred_reduzido = ridge.predict(X_reduzido_test)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# Criação da figura e do eixo tridimensional
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Gráfico de dispersão 3D
ax.scatter(X_reduzido_test[0], X_reduzido_test[1], y_pred_reduzido, c='b', marker='o', label='Pontos 3D')

# Adicionando rótulos aos eixos
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('Target')

# Adicionando um título ao gráfico
ax.set_title('Gráfico 3D de Dispersão')

# Exibindo a legenda
ax.legend()

# Exibindo o gráfico
plt.show()

# Salvando o gráfico como HTML usando Plotly
import plotly.graph_objects as go
plotly_fig = go.Figure(data=[go.Scatter3d(x=X_reduzido_test[0], y=X_reduzido_test[1], z=y_pred_reduzido, mode='markers')])
plotly_fig.write_html('grafico2.html')

# %% [markdown]
# # CONCLUSÃO

# %% [markdown]
# O modelo de regressão de Ridge adaptou-se bem ao dataset levando em conta a quantidade de exemplos presentes de diversos materiais supercondutores. Logo, pode-se dizer que o modelo é uma estratégia viável para previsão de características de materias, sendo interessante a sua aplicação para outros datasets dentro da área de propriedades de materiais.
#
# SPOILER: Ele desempenhou bem, mas não foi o menlhor, nem de longe. Aconselho olhar os outros notebooks.

# %% [markdown]
# ## Referências

# %% [markdown]
# 1.  Documentação do `optuna` [https://optuna.readthedocs.io/en/stable/index.html](https://optuna.readthedocs.io/en/stable/index.html)
#
# 2.  https://medium.com/@corymaklin/machine-learning-algorithms-part-11-ridge-regression-7d5861c2bc76
#
# 3. https://www.mygreatlearning.com/blog/what-is-ridge-regression/#:~:text=Ridge%20regression%20is%20a%20model,away%20from%20the%20actual%20values.
#
# 4. https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html
